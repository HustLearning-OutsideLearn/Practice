# %% [markdown]
# <a href="https://colab.research.google.com/github/KhoiDOO/Practice/blob/main/Incredible%20Techniques/1.%20Review_Classification_using_Active_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
# With the growth of data-centric Machine Learning, Active Learning has grown in popularity amongst businesses and researchers. Active Learning seeks to progressively train ML models so that the resultant model requires lesser amount of training data to achieve competitive scores.
#
# The structure of an Active Learning pipeline involves a classifier and an oracle. The oracle is an annotator that cleans, selects, labels the data, and feeds it to the model when required. The oracle is a trained individual or a group of individuals that ensure consistency in labeling of new data.
#
# The process starts with annotating a small subset of the full dataset and training an initial model. The best model checkpoint is saved and then tested on a balanced test set. The test set must be carefully sampled because the full training process will be dependent on it. Once we have the initial evaluation scores, the oracle is tasked with labeling more samples; the number of data points to be sampled is usually determined by the business requirements. After that, the newly sampled data is added to the training set, and the training procedure repeats. This cycle continues until either an acceptable score is reached or some other business metric is met.
#
# This tutorial provides a basic demonstration of how Active Learning works by demonstrating a ratio-based (least confidence) sampling strategy that results in lower overall false positive and negative rates when compared to a model trained on the entire dataset. This sampling falls under the domain of uncertanity sampling, in which new datasets are sampled based on the uncertanity that the model outputs for the corresponding label. In our example, we compare our model's false positive and false negative rates and annotate the new data based on their ratio.
#
# Some other sampling techniques include:
#
# Committee sampling: Using multiple models to vote for the best data points to be sampled
# Entropy reduction: Sampling according to an entropy threshold, selecting more of the samples that produce the highest entropy score.
# Minimum margin based sampling: Selects data points closest to the decision boundary

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import re
import string

# %% [markdown]
# # Loading and preprocessing the data
# We will be using the IMDB reviews dataset for our experiments. This dataset has 50,000 reviews in total, including training and testing splits. We will merge these splits and sample our own, balanced training, validation and testing sets.

# %%
dataset = tfds.load(
    "imdb_reviews",
    split="train + test",
    as_supervised=True,
    batch_size=-1,
    shuffle_files=False,
)
reviews, labels = tfds.as_numpy(dataset)

print("Total examples:", reviews.shape[0])
# Out:
# Downloading and preparing dataset imdb_reviews/plain_text/1.0.0 (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteK7Z417/imdb_reviews-train.tfrecord
#   0%|          | 0/25000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteK7Z417/imdb_reviews-test.tfrecord
#   0%|          | 0/25000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteK7Z417/imdb_reviews-unsupervised.tfrecord
#   0%|          | 0/50000 [00:00<?, ? examples/s]
# WARNING:absl:Dataset is using deprecated text encoder API which will be removed soon. Please use the plain_text version of the dataset and migrate to `tensorflow_text`.
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/dataset_builder.py:598: get_single_element (from tensorflow.python.data.experimental.ops.get_single_element) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.get_single_element()`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/dataset_builder.py:598: get_single_element (from tensorflow.python.data.experimental.ops.get_single_element) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.get_single_element()`.
# Total examples: 50000

# %% [markdown]
# Active learning starts with labeling a subset of data. For the ratio sampling technique that we will be using, we will need well-balanced training, validation and testing splits.

# %%
val_split = 2500
test_split = 2500
train_split = 7500

# Separating the negative and positive samples for manual stratification
x_positives, y_positives = reviews[labels == 1], labels[labels == 1]
x_negatives, y_negatives = reviews[labels == 0], labels[labels == 0]

# Creating training, validation and testing splits
x_val, y_val = (
    tf.concat((x_positives[:val_split], x_negatives[:val_split]), 0),
    tf.concat((y_positives[:val_split], y_negatives[:val_split]), 0),
)
x_test, y_test = (
    tf.concat(
        (
            x_positives[val_split : val_split + test_split],
            x_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split : val_split + test_split],
            y_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
)
x_train, y_train = (
    tf.concat(
        (
            x_positives[val_split + test_split : val_split + test_split + train_split],
            x_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split + test_split : val_split + test_split + train_split],
            y_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
)

# Remaining pool of samples are stored separately. These are only labeled as and when required
x_pool_positives, y_pool_positives = (
    x_positives[val_split + test_split + train_split :],
    y_positives[val_split + test_split + train_split :],
)
x_pool_negatives, y_pool_negatives = (
    x_negatives[val_split + test_split + train_split :],
    y_negatives[val_split + test_split + train_split :],
)

# Creating TF Datasets for faster prefetching and parallelization
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))

pool_negatives = tf.data.Dataset.from_tensor_slices(
    (x_pool_negatives, y_pool_negatives)
)
pool_positives = tf.data.Dataset.from_tensor_slices(
    (x_pool_positives, y_pool_positives)
)

print(f"Initial training set size: {len(train_dataset)}")
print(f"Validation set size: {len(val_dataset)}")
print(f"Testing set size: {len(test_dataset)}")
print(f"Unlabeled negative pool: {len(pool_negatives)}")
print(f"Unlabeled positive pool: {len(pool_positives)}")
# Out:
# Initial training set size: 15000
# Validation set size: 5000
# Testing set size: 5000
# Unlabeled negative pool: 12500
# Unlabeled positive pool: 12500

# %% [markdown]
# # Fitting the TextVectorization layer
# Since we are working with text data, we will need to encode the text strings as vectors which would then be passed through an Embedding layer. To make this tokenization process faster, we use the map() function with its parallelization functionality.

# %%
def custom_standardization(input_data):
    lowercase = tf.strings.lower(input_data)
    stripped_html = tf.strings.regex_replace(lowercase, "<br />", " ")
    return tf.strings.regex_replace(
        stripped_html, f"[{re.escape(string.punctuation)}]", ""
    )


vectorizer = layers.TextVectorization(
    3000, standardize=custom_standardization, output_sequence_length=150
)
# Adapting the dataset
vectorizer.adapt(
    train_dataset.map(lambda x, y: x, num_parallel_calls=tf.data.AUTOTUNE).batch(256)
)


def vectorize_text(text, label):
    text = vectorizer(text)
    return text, label


train_dataset = train_dataset.map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
).prefetch(tf.data.AUTOTUNE)
pool_negatives = pool_negatives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)
pool_positives = pool_positives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)

val_dataset = val_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)
test_dataset = test_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)

# %% [markdown]
# # Creating Helper Functions

# %%
# Helper function for merging new history objects with older ones
def append_history(losses, val_losses, accuracy, val_accuracy, history):
    losses = losses + history.history["loss"]
    val_losses = val_losses + history.history["val_loss"]
    accuracy = accuracy + history.history["binary_accuracy"]
    val_accuracy = val_accuracy + history.history["val_binary_accuracy"]
    return losses, val_losses, accuracy, val_accuracy


# Plotter function
def plot_history(losses, val_losses, accuracies, val_accuracies):
    plt.plot(losses)
    plt.plot(val_losses)
    plt.legend(["train_loss", "val_loss"])
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.show()

    plt.plot(accuracies)
    plt.plot(val_accuracies)
    plt.legend(["train_accuracy", "val_accuracy"])
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.show()

# %% [markdown]
# # Creating the Model
# We create a small bidirectional LSTM model. When using Active Learning, you should make sure that the model architecture is capable of overfitting to the initial data. Overfitting gives a strong hint that the model will have enough capacity for future, unseen data.

# %%
def create_model():
    model = keras.models.Sequential(
        [
            layers.Input(shape=(150,)),
            layers.Embedding(input_dim=3000, output_dim=128),
            layers.Bidirectional(layers.LSTM(32, return_sequences=True)),
            layers.GlobalMaxPool1D(),
            layers.Dense(20, activation="relu"),
            layers.Dropout(0.5),
            layers.Dense(1, activation="sigmoid"),
        ]
    )
    model.summary()
    return model

# %% [markdown]
# # Training on the entire dataset
# To show the effectiveness of Active Learning, we will first train the model on the entire dataset containing 40,000 labeled samples. This model will be used for comparison later.

# %%
def train_full_model(full_train_dataset, val_dataset, test_dataset):
    model = create_model()
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
        ],
    )

    # We will save the best model at every epoch and load the best one for evaluation on the test set
    history = model.fit(
        full_train_dataset.batch(256),
        epochs=20,
        validation_data=val_dataset,
        callbacks=[
            keras.callbacks.EarlyStopping(patience=4, verbose=1),
            keras.callbacks.ModelCheckpoint(
                "FullModelCheckpoint.h5", verbose=1, save_best_only=True
            ),
        ],
    )

    # Plot history
    plot_history(
        history.history["loss"],
        history.history["val_loss"],
        history.history["binary_accuracy"],
        history.history["val_binary_accuracy"],
    )

    # Loading the best checkpoint
    model = keras.models.load_model("FullModelCheckpoint.h5")

    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)
    return model


# Sampling the full train dataset to train on
full_train_dataset = (
    train_dataset.concatenate(pool_positives)
    .concatenate(pool_negatives)
    .cache()
    .shuffle(20000)
)

# Training the full model
full_dataset_model = train_full_model(full_train_dataset, val_dataset, test_dataset)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 128)          384000
#
#  bidirectional (Bidirectiona  (None, 150, 64)          41216
#  l)
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 20)                1300
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 426,537
# Trainable params: 426,537
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 157/157 [==============================] - ETA: 0s - loss: 0.5195 - binary_accuracy: 0.7598 - false_negatives: 2719.0000 - false_positives: 6888.0000
# Epoch 1: val_loss improved from inf to 0.38152, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 31s 113ms/step - loss: 0.5195 - binary_accuracy: 0.7598 - false_negatives: 2719.0000 - false_positives: 6888.0000 - val_loss: 0.3815 - val_binary_accuracy: 0.8502 - val_false_negatives: 409.0000 - val_false_positives: 340.0000
# Epoch 2/20
# 157/157 [==============================] - ETA: 0s - loss: 0.3678 - binary_accuracy: 0.8522 - false_negatives: 2967.0000 - false_positives: 2947.0000
# Epoch 2: val_loss improved from 0.38152 to 0.36860, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 11s 73ms/step - loss: 0.3678 - binary_accuracy: 0.8522 - false_negatives: 2967.0000 - false_positives: 2947.0000 - val_loss: 0.3686 - val_binary_accuracy: 0.8466 - val_false_negatives: 480.0000 - val_false_positives: 287.0000
# Epoch 3/20
# 157/157 [==============================] - ETA: 0s - loss: 0.3314 - binary_accuracy: 0.8669 - false_negatives: 2742.0000 - false_positives: 2580.0000
# Epoch 3: val_loss improved from 0.36860 to 0.35351, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 11s 68ms/step - loss: 0.3314 - binary_accuracy: 0.8669 - false_negatives: 2742.0000 - false_positives: 2580.0000 - val_loss: 0.3535 - val_binary_accuracy: 0.8566 - val_false_negatives: 432.0000 - val_false_positives: 285.0000
# Epoch 4/20
# 157/157 [==============================] - ETA: 0s - loss: 0.3122 - binary_accuracy: 0.8778 - false_negatives: 2452.0000 - false_positives: 2434.0000
# Epoch 4: val_loss improved from 0.35351 to 0.31591, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 11s 67ms/step - loss: 0.3122 - binary_accuracy: 0.8778 - false_negatives: 2452.0000 - false_positives: 2434.0000 - val_loss: 0.3159 - val_binary_accuracy: 0.8610 - val_false_negatives: 349.0000 - val_false_positives: 346.0000
# Epoch 5/20
# 157/157 [==============================] - ETA: 0s - loss: 0.2938 - binary_accuracy: 0.8869 - false_negatives: 2298.0000 - false_positives: 2225.0000
# Epoch 5: val_loss did not improve from 0.31591
# 157/157 [==============================] - 10s 66ms/step - loss: 0.2938 - binary_accuracy: 0.8869 - false_negatives: 2298.0000 - false_positives: 2225.0000 - val_loss: 0.4005 - val_binary_accuracy: 0.8084 - val_false_negatives: 854.0000 - val_false_positives: 104.0000
# Epoch 6/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.2807 - binary_accuracy: 0.8918 - false_negatives: 2292.0000 - false_positives: 2028.0000
# Epoch 6: val_loss did not improve from 0.31591
# 157/157 [==============================] - 10s 67ms/step - loss: 0.2807 - binary_accuracy: 0.8918 - false_negatives: 2294.0000 - false_positives: 2032.0000 - val_loss: 0.3424 - val_binary_accuracy: 0.8500 - val_false_negatives: 528.0000 - val_false_positives: 222.0000
# Epoch 7/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.2608 - binary_accuracy: 0.9006 - false_negatives: 2099.0000 - false_positives: 1872.0000
# Epoch 7: val_loss did not improve from 0.31591
# 157/157 [==============================] - 12s 74ms/step - loss: 0.2608 - binary_accuracy: 0.9006 - false_negatives: 2100.0000 - false_positives: 1877.0000 - val_loss: 0.3970 - val_binary_accuracy: 0.8262 - val_false_negatives: 713.0000 - val_false_positives: 156.0000
# Epoch 8/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.2488 - binary_accuracy: 0.9089 - false_negatives: 1915.0000 - false_positives: 1724.0000
# Epoch 8: val_loss did not improve from 0.31591
# 157/157 [==============================] - 10s 66ms/step - loss: 0.2491 - binary_accuracy: 0.9087 - false_negatives: 1922.0000 - false_positives: 1730.0000 - val_loss: 0.3315 - val_binary_accuracy: 0.8542 - val_false_negatives: 456.0000 - val_false_positives: 273.0000
# Epoch 8: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.3240821659564972, 'binary_accuracy': 0.8614000082015991, 'false_negatives': 362.0, 'false_positives': 331.0}
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Training via Active Learning
# The general process we follow when performing Active Learning is demonstrated below:
# ![image.png](data:image/png;base64,...)

# %%
def train_active_learning_models(
    train_dataset,
    pool_negatives,
    pool_positives,
    val_dataset,
    test_dataset,
    num_iterations=3,
    sampling_size=5000,
):

    # Creating lists for storing metrics
    losses, val_losses, accuracies, val_accuracies = [], [], [], []

    model = create_model()
    # We will monitor the false positives and false negatives predicted by our model
    # These will decide the subsequent sampling ratio for every Active Learning loop
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
        ],
    )

    # Defining checkpoints.
    # The checkpoint callback is reused throughout the training since it only saves the best overall model.
    checkpoint = keras.callbacks.ModelCheckpoint(
        "AL_Model.h5", save_best_only=True, verbose=1
    )
    # Here, patience is set to 4. This can be set higher if desired.
    early_stopping = keras.callbacks.EarlyStopping(patience=4, verbose=1)

    print(f"Starting to train with {len(train_dataset)} samples")
    # Initial fit with a small subset of the training set
    history = model.fit(
        train_dataset.cache().shuffle(20000).batch(256),
        epochs=20,
        validation_data=val_dataset,
        callbacks=[checkpoint, early_stopping],
    )

    # Appending history
    losses, val_losses, accuracies, val_accuracies = append_history(
        losses, val_losses, accuracies, val_accuracies, history
    )

    for iteration in range(num_iterations):
        # Getting predictions from previously trained model
        predictions = model.predict(test_dataset)

        # Generating labels from the output probabilities
        rounded = tf.where(tf.greater(predictions, 0.5), 1, 0)

        # Evaluating the number of zeros and ones incorrrectly classified
        _, _, false_negatives, false_positives = model.evaluate(test_dataset, verbose=0)

        print("-" * 100)
        print(
            f"Number of zeros incorrectly classified: {false_negatives}, Number of ones incorrectly classified: {false_positives}"
        )

        # This technique of Active Learning demonstrates ratio based sampling where
        # Number of ones/zeros to sample = Number of ones/zeros incorrectly classified / Total incorrectly classified
        if false_negatives != 0 and false_positives != 0:
            total = false_negatives + false_positives
            sample_ratio_ones, sample_ratio_zeros = (
                false_positives / total,
                false_negatives / total,
            )
        # In the case where all samples are correctly predicted, we can sample both classes equally
        else:
            sample_ratio_ones, sample_ratio_zeros = 0.5, 0.5

        print(
            f"Sample ratio for positives: {sample_ratio_ones}, Sample ratio for negatives:{sample_ratio_zeros}"
        )

        # Sample the required number of ones and zeros
        sampled_dataset = pool_negatives.take(
            int(sample_ratio_zeros * sampling_size)
        ).concatenate(pool_positives.take(int(sample_ratio_ones * sampling_size)))

        # Skip the sampled data points to avoid repetition of sample
        pool_negatives = pool_negatives.skip(int(sample_ratio_zeros * sampling_size))
        pool_positives = pool_positives.skip(int(sample_ratio_ones * sampling_size))

        # Concatenating the train_dataset with the sampled_dataset
        train_dataset = train_dataset.concatenate(sampled_dataset).prefetch(
            tf.data.AUTOTUNE
        )

        print(f"Starting training with {len(train_dataset)} samples")
        print("-" * 100)

        # We recompile the model to reset the optimizer states and retrain the model
        model.compile(
            loss="binary_crossentropy",
            optimizer="rmsprop",
            metrics=[
                keras.metrics.BinaryAccuracy(),
                keras.metrics.FalseNegatives(),
                keras.metrics.FalsePositives(),
            ],
        )
        history = model.fit(
            train_dataset.cache().shuffle(20000).batch(256),
            validation_data=val_dataset,
            epochs=20,
            callbacks=[
                checkpoint,
                keras.callbacks.EarlyStopping(patience=4, verbose=1),
            ],
        )

        # Appending the history
        losses, val_losses, accuracies, val_accuracies = append_history(
            losses, val_losses, accuracies, val_accuracies, history
        )

        # Loading the best model from this training loop
        model = keras.models.load_model("AL_Model.h5")

    # Plotting the overall history and evaluating the final model
    plot_history(losses, val_losses, accuracies, val_accuracies)
    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)

    return model


active_learning_model = train_active_learning_models(
    train_dataset, pool_negatives, pool_positives, val_dataset, test_dataset
)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 150, 128)          384000
#
#  bidirectional_1 (Bidirectio  (None, 150, 64)          41216
#  nal)
#
#  global_max_pooling1d_1 (Glo  (None, 64)               0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (None, 20)                1300
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_3 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 426,537
# Trainable params: 426,537
# Non-trainable params: 0
# _________________________________________________________________
# Starting to train with 15000 samples
# Epoch 1/20
# 59/59 [==============================] - ETA: 0s - loss: 0.6377 - binary_accuracy: 0.6378 - false_negatives_1: 3177.0000 - false_positives_1: 2256.0000
# Epoch 1: val_loss improved from inf to 0.54964, saving model to AL_Model.h5
# 59/59 [==============================] - 13s 99ms/step - loss: 0.6377 - binary_accuracy: 0.6378 - false_negatives_1: 3177.0000 - false_positives_1: 2256.0000 - val_loss: 0.5496 - val_binary_accuracy: 0.7108 - val_false_negatives_1: 58.0000 - val_false_positives_1: 1388.0000
# Epoch 2/20
# 59/59 [==============================] - ETA: 0s - loss: 0.4389 - binary_accuracy: 0.8144 - false_negatives_1: 1237.0000 - false_positives_1: 1547.0000
# Epoch 2: val_loss improved from 0.54964 to 0.38240, saving model to AL_Model.h5
# 59/59 [==============================] - 4s 75ms/step - loss: 0.4389 - binary_accuracy: 0.8144 - false_negatives_1: 1237.0000 - false_positives_1: 1547.0000 - val_loss: 0.3824 - val_binary_accuracy: 0.8388 - val_false_negatives_1: 279.0000 - val_false_positives_1: 527.0000
# Epoch 3/20
# 59/59 [==============================] - ETA: 0s - loss: 0.3730 - binary_accuracy: 0.8507 - false_negatives_1: 1025.0000 - false_positives_1: 1215.0000
# Epoch 3: val_loss improved from 0.38240 to 0.35555, saving model to AL_Model.h5
# 59/59 [==============================] - 4s 72ms/step - loss: 0.3730 - binary_accuracy: 0.8507 - false_negatives_1: 1025.0000 - false_positives_1: 1215.0000 - val_loss: 0.3555 - val_binary_accuracy: 0.8482 - val_false_negatives_1: 243.0000 - val_false_positives_1: 516.0000
# Epoch 4/20
# 59/59 [==============================] - ETA: 0s - loss: 0.3268 - binary_accuracy: 0.8719 - false_negatives_1: 892.0000 - false_positives_1: 1030.0000
# Epoch 4: val_loss did not improve from 0.35555
# 59/59 [==============================] - 4s 73ms/step - loss: 0.3268 - binary_accuracy: 0.8719 - false_negatives_1: 892.0000 - false_positives_1: 1030.0000 - val_loss: 0.4522 - val_binary_accuracy: 0.8078 - val_false_negatives_1: 110.0000 - val_false_positives_1: 851.0000
# Epoch 5/20
# 59/59 [==============================] - ETA: 0s - loss: 0.3091 - binary_accuracy: 0.8829 - false_negatives_1: 827.0000 - false_positives_1: 929.0000
# Epoch 5: val_loss did not improve from 0.35555
# 59/59 [==============================] - 4s 69ms/step - loss: 0.3091 - binary_accuracy: 0.8829 - false_negatives_1: 827.0000 - false_positives_1: 929.0000 - val_loss: 0.3655 - val_binary_accuracy: 0.8466 - val_false_negatives_1: 275.0000 - val_false_positives_1: 492.0000
# Epoch 6/20
# 59/59 [==============================] - ETA: 0s - loss: 0.2851 - binary_accuracy: 0.8921 - false_negatives_1: 795.0000 - false_positives_1: 824.0000
# Epoch 6: val_loss did not improve from 0.35555
# 59/59 [==============================] - 4s 69ms/step - loss: 0.2851 - binary_accuracy: 0.8921 - false_negatives_1: 795.0000 - false_positives_1: 824.0000 - val_loss: 0.3798 - val_binary_accuracy: 0.8398 - val_false_negatives_1: 514.0000 - val_false_positives_1: 287.0000
# Epoch 7/20
# 59/59 [==============================] - ETA: 0s - loss: 0.2669 - binary_accuracy: 0.8995 - false_negatives_1: 745.0000 - false_positives_1: 763.0000
# Epoch 7: val_loss did not improve from 0.35555
# 59/59 [==============================] - 4s 69ms/step - loss: 0.2669 - binary_accuracy: 0.8995 - false_negatives_1: 745.0000 - false_positives_1: 763.0000 - val_loss: 0.3614 - val_binary_accuracy: 0.8470 - val_false_negatives_1: 370.0000 - val_false_positives_1: 395.0000
# Epoch 7: early stopping
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 421.0, Number of ones incorrectly classified: 366.0
# Sample ratio for positives: 0.4650571791613723, Sample ratio for negatives:0.5349428208386277
# Starting training with 19999 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 78/79 [============================>.] - ETA: 0s - loss: 0.3010 - binary_accuracy: 0.8868 - false_negatives_2: 1075.0000 - false_positives_2: 1186.0000
# Epoch 1: val_loss did not improve from 0.35555
# 79/79 [==============================] - 15s 79ms/step - loss: 0.3007 - binary_accuracy: 0.8868 - false_negatives_2: 1076.0000 - false_positives_2: 1187.0000 - val_loss: 0.3694 - val_binary_accuracy: 0.8512 - val_false_negatives_2: 363.0000 - val_false_positives_2: 381.0000
# Epoch 2/20
# 79/79 [==============================] - ETA: 0s - loss: 0.2663 - binary_accuracy: 0.9009 - false_negatives_2: 960.0000 - false_positives_2: 1022.0000
# Epoch 2: val_loss did not improve from 0.35555
# 79/79 [==============================] - 6s 76ms/step - loss: 0.2663 - binary_accuracy: 0.9009 - false_negatives_2: 960.0000 - false_positives_2: 1022.0000 - val_loss: 0.4180 - val_binary_accuracy: 0.8214 - val_false_negatives_2: 157.0000 - val_false_positives_2: 736.0000
# Epoch 3/20
# 78/79 [============================>.] - ETA: 0s - loss: 0.2462 - binary_accuracy: 0.9104 - false_negatives_2: 863.0000 - false_positives_2: 926.0000
# Epoch 3: val_loss did not improve from 0.35555
# 79/79 [==============================] - 6s 74ms/step - loss: 0.2462 - binary_accuracy: 0.9103 - false_negatives_2: 867.0000 - false_positives_2: 927.0000 - val_loss: 0.3689 - val_binary_accuracy: 0.8470 - val_false_negatives_2: 373.0000 - val_false_positives_2: 392.0000
# Epoch 4/20
# 78/79 [============================>.] - ETA: 0s - loss: 0.2259 - binary_accuracy: 0.9199 - false_negatives_2: 806.0000 - false_positives_2: 793.0000
# Epoch 4: val_loss did not improve from 0.35555
# 79/79 [==============================] - 6s 74ms/step - loss: 0.2259 - binary_accuracy: 0.9199 - false_negatives_2: 809.0000 - false_positives_2: 793.0000 - val_loss: 0.4117 - val_binary_accuracy: 0.8368 - val_false_negatives_2: 257.0000 - val_false_positives_2: 559.0000
# Epoch 5/20
# 79/79 [==============================] - ETA: 0s - loss: 0.2111 - binary_accuracy: 0.9270 - false_negatives_2: 726.0000 - false_positives_2: 734.0000
# Epoch 5: val_loss did not improve from 0.35555
# 79/79 [==============================] - 6s 72ms/step - loss: 0.2111 - binary_accuracy: 0.9270 - false_negatives_2: 726.0000 - false_positives_2: 734.0000 - val_loss: 0.4912 - val_binary_accuracy: 0.8248 - val_false_negatives_2: 183.0000 - val_false_positives_2: 693.0000
# Epoch 6/20
# 79/79 [==============================] - ETA: 0s - loss: 0.1966 - binary_accuracy: 0.9338 - false_negatives_2: 652.0000 - false_positives_2: 671.0000
# Epoch 6: val_loss did not improve from 0.35555
# 79/79 [==============================] - 6s 71ms/step - loss: 0.1966 - binary_accuracy: 0.9338 - false_negatives_2: 652.0000 - false_positives_2: 671.0000 - val_loss: 0.4445 - val_binary_accuracy: 0.8404 - val_false_negatives_2: 301.0000 - val_false_positives_2: 497.0000
# Epoch 7/20
# 79/79 [==============================] - ETA: 0s - loss: 0.1819 - binary_accuracy: 0.9384 - false_negatives_2: 608.0000 - false_positives_2: 623.0000
# Epoch 7: val_loss did not improve from 0.35555
# 79/79 [==============================] - 6s 75ms/step - loss: 0.1819 - binary_accuracy: 0.9384 - false_negatives_2: 608.0000 - false_positives_2: 623.0000 - val_loss: 0.4513 - val_binary_accuracy: 0.8398 - val_false_negatives_2: 334.0000 - val_false_positives_2: 467.0000
# Epoch 7: early stopping
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 286.0, Number of ones incorrectly classified: 500.0
# Sample ratio for positives: 0.6361323155216285, Sample ratio for negatives:0.3638676844783715
# Starting training with 24998 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 98/98 [==============================] - ETA: 0s - loss: 0.3702 - binary_accuracy: 0.8554 - false_negatives_3: 1748.0000 - false_positives_3: 1866.0000
# Epoch 1: val_loss improved from 0.35555 to 0.35166, saving model to AL_Model.h5
# 98/98 [==============================] - 19s 88ms/step - loss: 0.3702 - binary_accuracy: 0.8554 - false_negatives_3: 1748.0000 - false_positives_3: 1866.0000 - val_loss: 0.3517 - val_binary_accuracy: 0.8448 - val_false_negatives_3: 522.0000 - val_false_positives_3: 254.0000
# Epoch 2/20
# 98/98 [==============================] - ETA: 0s - loss: 0.3250 - binary_accuracy: 0.8710 - false_negatives_3: 1568.0000 - false_positives_3: 1656.0000
# Epoch 2: val_loss did not improve from 0.35166
# 98/98 [==============================] - 6s 66ms/step - loss: 0.3250 - binary_accuracy: 0.8710 - false_negatives_3: 1568.0000 - false_positives_3: 1656.0000 - val_loss: 0.3517 - val_binary_accuracy: 0.8464 - val_false_negatives_3: 528.0000 - val_false_positives_3: 240.0000
# Epoch 3/20
# 98/98 [==============================] - ETA: 0s - loss: 0.3020 - binary_accuracy: 0.8850 - false_negatives_3: 1412.0000 - false_positives_3: 1464.0000
# Epoch 3: val_loss did not improve from 0.35166
# 98/98 [==============================] - 6s 66ms/step - loss: 0.3020 - binary_accuracy: 0.8850 - false_negatives_3: 1412.0000 - false_positives_3: 1464.0000 - val_loss: 0.3597 - val_binary_accuracy: 0.8480 - val_false_negatives_3: 224.0000 - val_false_positives_3: 536.0000
# Epoch 4/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2816 - binary_accuracy: 0.8931 - false_negatives_3: 1289.0000 - false_positives_3: 1384.0000
# Epoch 4: val_loss improved from 0.35166 to 0.34487, saving model to AL_Model.h5
# 98/98 [==============================] - 7s 75ms/step - loss: 0.2816 - binary_accuracy: 0.8931 - false_negatives_3: 1289.0000 - false_positives_3: 1384.0000 - val_loss: 0.3449 - val_binary_accuracy: 0.8466 - val_false_negatives_3: 483.0000 - val_false_positives_3: 284.0000
# Epoch 5/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2651 - binary_accuracy: 0.9024 - false_negatives_3: 1213.0000 - false_positives_3: 1226.0000
# Epoch 5: val_loss improved from 0.34487 to 0.34287, saving model to AL_Model.h5
# 98/98 [==============================] - 7s 69ms/step - loss: 0.2651 - binary_accuracy: 0.9024 - false_negatives_3: 1213.0000 - false_positives_3: 1226.0000 - val_loss: 0.3429 - val_binary_accuracy: 0.8518 - val_false_negatives_3: 360.0000 - val_false_positives_3: 381.0000
# Epoch 6/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2467 - binary_accuracy: 0.9092 - false_negatives_3: 1097.0000 - false_positives_3: 1172.0000
# Epoch 6: val_loss did not improve from 0.34287
# 98/98 [==============================] - 7s 71ms/step - loss: 0.2467 - binary_accuracy: 0.9092 - false_negatives_3: 1097.0000 - false_positives_3: 1172.0000 - val_loss: 0.3819 - val_binary_accuracy: 0.8460 - val_false_negatives_3: 228.0000 - val_false_positives_3: 542.0000
# Epoch 7/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2323 - binary_accuracy: 0.9165 - false_negatives_3: 1008.0000 - false_positives_3: 1080.0000
# Epoch 7: val_loss did not improve from 0.34287
# 98/98 [==============================] - 7s 68ms/step - loss: 0.2323 - binary_accuracy: 0.9165 - false_negatives_3: 1008.0000 - false_positives_3: 1080.0000 - val_loss: 0.3916 - val_binary_accuracy: 0.8442 - val_false_negatives_3: 224.0000 - val_false_positives_3: 555.0000
# Epoch 8/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2156 - binary_accuracy: 0.9245 - false_negatives_3: 914.0000 - false_positives_3: 974.0000
# Epoch 8: val_loss did not improve from 0.34287
# 98/98 [==============================] - 7s 66ms/step - loss: 0.2156 - binary_accuracy: 0.9245 - false_negatives_3: 914.0000 - false_positives_3: 974.0000 - val_loss: 0.4138 - val_binary_accuracy: 0.8430 - val_false_negatives_3: 311.0000 - val_false_positives_3: 474.0000
# Epoch 9/20
# 98/98 [==============================] - ETA: 0s - loss: 0.1989 - binary_accuracy: 0.9308 - false_negatives_3: 858.0000 - false_positives_3: 872.0000
# Epoch 9: val_loss did not improve from 0.34287
# 98/98 [==============================] - 8s 78ms/step - loss: 0.1989 - binary_accuracy: 0.9308 - false_negatives_3: 858.0000 - false_positives_3: 872.0000 - val_loss: 0.4410 - val_binary_accuracy: 0.8424 - val_false_negatives_3: 287.0000 - val_false_positives_3: 501.0000
# Epoch 9: early stopping
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 371.0, Number of ones incorrectly classified: 352.0
# Sample ratio for positives: 0.48686030428769017, Sample ratio for negatives:0.5131396957123098
# Starting training with 29997 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 118/118 [==============================] - ETA: 0s - loss: 0.2770 - binary_accuracy: 0.8955 - false_negatives_4: 1517.0000 - false_positives_4: 1617.0000
# Epoch 1: val_loss did not improve from 0.34287
# 118/118 [==============================] - 22s 108ms/step - loss: 0.2770 - binary_accuracy: 0.8955 - false_negatives_4: 1517.0000 - false_positives_4: 1617.0000 - val_loss: 0.3918 - val_binary_accuracy: 0.8382 - val_false_negatives_4: 213.0000 - val_false_positives_4: 596.0000
# Epoch 2/20
# 118/118 [==============================] - ETA: 0s - loss: 0.2523 - binary_accuracy: 0.9062 - false_negatives_4: 1382.0000 - false_positives_4: 1431.0000
# Epoch 2: val_loss did not improve from 0.34287
# 118/118 [==============================] - 8s 69ms/step - loss: 0.2523 - binary_accuracy: 0.9062 - false_negatives_4: 1382.0000 - false_positives_4: 1431.0000 - val_loss: 0.3694 - val_binary_accuracy: 0.8378 - val_false_negatives_4: 578.0000 - val_false_positives_4: 233.0000
# Epoch 3/20
# 117/118 [============================>.] - ETA: 0s - loss: 0.2396 - binary_accuracy: 0.9136 - false_negatives_4: 1289.0000 - false_positives_4: 1300.0000
# Epoch 3: val_loss did not improve from 0.34287
# 118/118 [==============================] - 8s 68ms/step - loss: 0.2394 - binary_accuracy: 0.9136 - false_negatives_4: 1290.0000 - false_positives_4: 1301.0000 - val_loss: 0.3561 - val_binary_accuracy: 0.8516 - val_false_negatives_4: 349.0000 - val_false_positives_4: 393.0000
# Epoch 4/20
# 117/118 [============================>.] - ETA: 0s - loss: 0.2241 - binary_accuracy: 0.9213 - false_negatives_4: 1157.0000 - false_positives_4: 1201.0000
# Epoch 4: val_loss did not improve from 0.34287
# 118/118 [==============================] - 8s 65ms/step - loss: 0.2243 - binary_accuracy: 0.9212 - false_negatives_4: 1157.0000 - false_positives_4: 1207.0000 - val_loss: 0.3944 - val_binary_accuracy: 0.8370 - val_false_negatives_4: 585.0000 - val_false_positives_4: 230.0000
# Epoch 5/20
# 117/118 [============================>.] - ETA: 0s - loss: 0.2064 - binary_accuracy: 0.9285 - false_negatives_4: 1057.0000 - false_positives_4: 1084.0000
# Epoch 5: val_loss did not improve from 0.34287
# 118/118 [==============================] - 8s 64ms/step - loss: 0.2064 - binary_accuracy: 0.9285 - false_negatives_4: 1058.0000 - false_positives_4: 1087.0000 - val_loss: 0.5621 - val_binary_accuracy: 0.8142 - val_false_negatives_4: 754.0000 - val_false_positives_4: 175.0000
# Epoch 6/20
# 117/118 [============================>.] - ETA: 0s - loss: 0.1942 - binary_accuracy: 0.9339 - false_negatives_4: 957.0000 - false_positives_4: 1023.0000
# Epoch 6: val_loss did not improve from 0.34287
# 118/118 [==============================] - 8s 70ms/step - loss: 0.1943 - binary_accuracy: 0.9338 - false_negatives_4: 960.0000 - false_positives_4: 1026.0000 - val_loss: 0.4930 - val_binary_accuracy: 0.8226 - val_false_negatives_4: 162.0000 - val_false_positives_4: 725.0000
# Epoch 7/20
# 118/118 [==============================] - ETA: 0s - loss: 0.1811 - binary_accuracy: 0.9393 - false_negatives_4: 896.0000 - false_positives_4: 924.0000
# Epoch 7: val_loss did not improve from 0.34287
# 118/118 [==============================] - 8s 68ms/step - loss: 0.1811 - binary_accuracy: 0.9393 - false_negatives_4: 896.0000 - false_positives_4: 924.0000 - val_loss: 0.5243 - val_binary_accuracy: 0.8216 - val_false_negatives_4: 172.0000 - val_false_positives_4: 720.0000
# Epoch 7: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.34614044427871704, 'binary_accuracy': 0.855400025844574, 'false_negatives_3': 371.0, 'false_positives_3': 352.0}
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Conclusion
# Active Learning is a growing area of research. This example demonstrates the cost-efficiency benefits of using Active Learning, as it eliminates the need to annotate large amounts of data, saving resources.
#
# The following are some noteworthy observations from this example:
# - The model only require 30,000 samples to reach the same (if not better) scores as the model trained on the full datatset. This means that in a real life setting, we save the effort required for annotating 10,000 images!
# - The number of false negatives and false positives are well balanced at the end of the training as compared to the skewed ratio obtained from the full training. This makes the model slightly more useful in real life scenarios where both the labels hold equal importance.
#
# Further Reading:
# - https://burrsettles.com/pub/settles.activelearning.pdf
# - https://github.com/modAL-python/modAL
# - https://github.com/google/active-learning
